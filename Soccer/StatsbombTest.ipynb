# %%
from statsbombpy import sb

# %%
sb.competitions()
# Out:
# credentials were not supplied. open data access only
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# ...

# %%
matchesLiga = sb.matches(competition_id=11,season_id=42)
# Out:
# credentials were not supplied. open data access only

# %%
matchesLiga
# Out:
#     match_id  match_date      kick_off      competition     season  \
# 0     303421  2020-07-19  17:00:00.000  Spain - La Liga  2019/2020
# 1     303493  2020-06-23  22:00:00.000  Spain - La Liga  2019/2020
# 2     303516  2020-06-27  17:00:00.000  Spain - La Liga  2019/2020
# 3     303680  2020-07-11  19:30:00.000  Spain - La Liga  2019/2020
# 4     303532  2020-06-16  22:00:00.000  Spain - La Liga  2019/2020
# 5     303400  2020-01-25  16:00:00.000  Spain - La Liga  2019/2020
# 6     303634  2020-07-16  21:00:00.000  Spain - La Liga  2019/2020
# 7     303479  2020-03-07  18:30:00.000  Spain - La Liga  2019/2020
# 8     303615  2020-07-08  22:00:00.000  Spain - La Liga  2019/2020
# 9     303696  2020-06-30  22:00:00.000  Spain - La Liga  2019/2020
# 10    303664  2019-12-14  16:00:00.000  Spain - La Liga  2019/2020
# 11    303596  2019-12-18  20:00:00.000  Spain - La Liga  2019/2020
# 12    303487  2019-11-09  21:00:00.000  Spain - La Liga  2019/2020
# ...

# %%
events = sb.events(match_id=303596)
# Out:
# credentials were not supplied. open data access only

# %%
events
# Out:
#      50_50 ball_receipt_outcome ball_recovery_recovery_failure  \
# 0      NaN                  NaN                            NaN
# 1      NaN                  NaN                            NaN
# 2      NaN                  NaN                            NaN
# 3      NaN                  NaN                            NaN
# 4      NaN                  NaN                            NaN
# ...    ...                  ...                            ...
# 4153   NaN                  NaN                            NaN
# 4154   NaN                  NaN                            NaN
# 4155   NaN                  NaN                            NaN
# 4156   NaN                  NaN                            NaN
# 4157   NaN                  NaN                            NaN
#
#      block_save_block carry_end_location clearance_aerial_won  \
# 0                 NaN                NaN                  NaN
# 1                 NaN                NaN                  NaN
# ...

# %%
passing = sb.events(match_id=303596, split=True, flatten_attrs=False)["passes"]
# Out:
# credentials were not supplied. open data access only

# %%
passing
# Out:
#                                         id  index  period     timestamp  \
# 0     e4422312-0438-4b6a-bc07-873768c96460      5       1  00:00:00.440
# 1     fcd3ef3e-0a24-4337-b9d1-23c72e85dce4      8       1  00:00:02.273
# 2     e02765f6-f42b-4dca-82f8-8066777566e2     11       1  00:00:03.832
# 3     ebe46ce9-1c00-4b98-8dfe-5f41f3bc606d     14       1  00:00:04.628
# 4     49fdff37-6b4a-4cf0-8335-21601c790dcc     17       1  00:00:05.512
# ...                                    ...    ...     ...           ...
# 1180  7ae98f11-9ae5-417a-9601-c58474a75e9d   4141       2  00:49:27.052
# 1181  fd954704-6ada-4c46-a777-0e061795ac56   4146       2  00:49:28.790
# 1182  7e8c3f69-bdba-47b2-9b70-64c938208607   4148       2  00:49:30.551
# 1183  11199981-d825-4c3b-8816-dfa83fd7959f   4153       2  00:49:34.053
# 1184  a05e7b95-3bbb-4e27-82e5-a7a8a08b6b55   4155       2  00:49:52.584
#
#       minute  second  type  possession possession_team   play_pattern  ...  \
# ...

# %%
passing = passing.drop(['position','index','timestamp','period','related_events','match_id','under_pressure','off_camera','counterpress','pass','duration','id','type'],axis=1)

# %%
passing[passing['player']=='Karim Benzema']
# Out:
#       minute  second  possession possession_team    play_pattern         team  \
# 0          0       0           2     Real Madrid   From Kick Off  Real Madrid
# 103        6       8          12     Real Madrid   From Throw In  Real Madrid
# 111        6      31          12     Real Madrid   From Throw In  Real Madrid
# 160        9      24          17     Real Madrid    Regular Play  Real Madrid
# 195       12      10          37     Real Madrid    Regular Play  Real Madrid
# 211       13      11          39     Real Madrid    Regular Play  Real Madrid
# 214       13      19          39     Real Madrid    Regular Play  Real Madrid
# 225       14      10          41     Real Madrid   From Throw In  Real Madrid
# 238       14      46          43     Real Madrid    Regular Play  Real Madrid
# 255       15      54          44     Real Madrid   From Throw In  Real Madrid
# 257       15      58          44     Real Madrid   From Throw In  Real Madrid
# ...
