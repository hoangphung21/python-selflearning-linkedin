# %%
import pandas as pd
import matplotlib.pyplot as pls
from soccerplots.radar_chart import Radar

# %%
#read in the data
df = pd.read_csv('radars20202021.csv')

# %%
df.head()
# Out:
#    Rk               Player   Nation Pos           Squad   Age    Born   90s  \
# 0   1  Patrick van Aanholt   nl NED  DF  Crystal Palace  29.0  1990.0  19.7
# 1   2        Tammy Abraham  eng ENG  FW         Chelsea  22.0  1997.0  11.6
# 2   3            Che Adams  sco SCO  FW     Southampton  24.0  1996.0  29.6
# 3   4     Tosin Adarabioyo  eng ENG  DF          Fulham  22.0  1997.0  32.8
# 4   5               Adrián   es ESP  GK       Liverpool  33.0  1987.0   3.0
#
#    Gls  Sh  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  \
# 0    0  18  ...  20.3   3   0      0  1.2   1.2     0.07  -1.2     -1.2
# 1    6  32  ...   9.7   0   0      0  6.4   6.4     0.20  -0.4     -0.4
# 2    9  56  ...  13.1   0   0      0  8.8   8.8     0.16   0.2      0.2
# 3    0  20  ...   8.8   0   0      0  1.1   1.1     0.05  -1.1     -1.1
# 4    0   0  ...   NaN   0   0      0  0.0   0.0      NaN   0.0      0.0
#
#    Matches
# 0  Matches
# 1  Matches
# 2  Matches
# 3  Matches
# 4  Matches
# ...

# %%
df['Player'] = df['Player'].str.split('\\',expand=True)[0]

# %%
df.head()
# Out:
#    Rk               Player   Nation Pos           Squad   Age    Born   90s  \
# 0   1  Patrick van Aanholt   nl NED  DF  Crystal Palace  29.0  1990.0  19.7
# 1   2        Tammy Abraham  eng ENG  FW         Chelsea  22.0  1997.0  11.6
# 2   3            Che Adams  sco SCO  FW     Southampton  24.0  1996.0  29.6
# 3   4     Tosin Adarabioyo  eng ENG  DF          Fulham  22.0  1997.0  32.8
# 4   5               Adrián   es ESP  GK       Liverpool  33.0  1987.0   3.0
#
#    Gls  Sh  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  \
# 0    0  18  ...  20.3   3   0      0  1.2   1.2     0.07  -1.2     -1.2
# 1    6  32  ...   9.7   0   0      0  6.4   6.4     0.20  -0.4     -0.4
# 2    9  56  ...  13.1   0   0      0  8.8   8.8     0.16   0.2      0.2
# 3    0  20  ...   8.8   0   0      0  1.1   1.1     0.05  -1.1     -1.1
# 4    0   0  ...   NaN   0   0      0  0.0   0.0      NaN   0.0      0.0
#
#    Matches
# 0  Matches
# 1  Matches
# 2  Matches
# 3  Matches
# 4  Matches
# ...

# %%
df = df[(df['Player']=='Cristiano Ronaldo') | (df['Player']=='Lionel Messi')].reset_index()

# %%
df
# Out:
#    index   Rk           Player   Nation Pos           Squad   Age    Born  \
# 0    235  236       Harry Kane  eng ENG  FW       Tottenham  27.0  1993.0
# 1    389  390  Marcus Rashford  eng ENG  FW  Manchester Utd  22.0  1997.0
#
#     90s  Gls  ...  Dist  FK  PK  PKatt    xG  npxG  npxG/Sh  G-xG  np:G-xG  \
# 0  34.2   23  ...  17.7  14   4      4  20.5  17.5     0.13   2.5      1.5
# 1  32.4   11  ...  18.4   5   0      0   9.3   9.3     0.12   1.7      1.7
#
#    Matches
# 0  Matches
# 1  Matches
#
# [2 rows x 27 columns]

# %%
df = df.drop(['index','Rk','Nation','Pos','Squad','Age','Born','90s','PKatt','FK','PK','Matches'],axis=1)

# %%
df
# Out:
#             Player  Gls   Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  Dist  \
# 0       Harry Kane   23  134   47  35.1   3.91    1.37  0.14   0.40  17.7
# 1  Marcus Rashford   11   79   36  45.6   2.43    1.11  0.14   0.31  18.4
#
#      xG  npxG  npxG/Sh  G-xG  np:G-xG
# 0  20.5  17.5     0.13   2.5      1.5
# 1   9.3   9.3     0.12   1.7      1.7

# %%
#get parameters
params = list(df.columns)
params = params[1:]
params
# Out:
# ['Gls',
#  'Sh',
#  'SoT',
#  'SoT%',
#  'Sh/90',
#  'SoT/90',
#  'G/Sh',
#  'G/SoT',
#  'Dist',
#  'xG',
#  'npxG',
#  'npxG/Sh',
#  'G-xG',
#  'np:G-xG']

# %%
# add ranges to list of tuple pairs
ranges = []
a_values = []
b_values = []

for x in params:
    a = min(df[params][x])
    a = a - (a*0.25)
    
    b = max(df[params][x])
    b = b+ (b*0.25)
    
    ranges.append((a,b))
    
for x in range(len(df['Player'])):
    if df['Player'][x] == 'Harry Kane':
        a_values = df.iloc[x].values.tolist()
    if df['Player'][x] == 'Marcus Rashford':
        b_values = df.iloc[x].values.tolist()

a_values=a_values[1:]
b_values=b_values[1:]

values =[a_values,b_values]

# %%
values
# Out:
# [[23, 134, 47, 35.1, 3.91, 1.37, 0.14, 0.4, 17.7, 20.5, 17.5, 0.13, 2.5, 1.5],
#  [11, 79, 36, 45.6, 2.43, 1.11, 0.14, 0.31, 18.4, 9.3, 9.3, 0.12, 1.7, 1.7]]

# %%
# title

title = dict(
    title_name = 'Harry Kane',
    title_color = 'grey',
    subtitle_name = 'Tottenham Hotspur F.C.',
    subtitle_color = 'grey',
    title_name_2 = 'Marcus Rashford',
    title_color_2 = 'red',
    subtitle_name_2 = 'Manchester United F.C.',
    subtitle_color_2 = 'red',
    title_fontsize = 18,
    subtitle_fontsize = 15
)

# %%
radar = Radar()

fig,ax = radar.plot_radar(ranges=ranges,params=params,values=values,radar_color=['grey','red'],alphas=[.75,.6],title=title,compare=True,figsize=(350,50))
